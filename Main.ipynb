# %%
#import all packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
path="C:\\Users\\user\\OneDrive - Ayooluwa Shofolahan\\YUSUF\\YUSUF\\DATA SCIENCE COURSE\\MACHINE LEARNING\\train.csv"

# %%
train = pd.read_csv(path)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Data Accessing

# %%
# print the first five rows of the DataFrame
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# print the last five rows of the DataFrame
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# randomly print 10 rows from the DataFrame
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 635          636         1       2                 Davis, Miss. Mary  female
# 756          757         0       3      Carlsson, Mr. August Sigfrid    male
# 795          796         0       2                Otter, Mr. Richard    male
# 545          546         0       1      Nicholson, Mr. Arthur Ernest    male
# 747          748         1       2             Sinkkonen, Miss. Anna  female
# 262          263         0       1                 Taussig, Mr. Emil    male
# 197          198         0       3  Olsen, Mr. Karl Siegwart Andreas    male
# 403          404         0       3    Hakkarainen, Mr. Pekka Pietari    male
# 790          791         0       3          Keane, Mr. Andrew "Andy"    male
# 357          358         0       2         Funk, Miss. Annie Clemmer  female
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Show the summary of the DataFrame
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # The DF has the below info:
#
# 891 rows & 12 columns
# Age datatype should be changed from float to integer
# All missing figures in the age, cabin & embarked columns will be amended during data cleaning phase

# %%
train.shape
# Out:
# (891, 12)

# %%
# Check for missing values
missing_values = train.isna().sum()
missing_values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.shape[0]
# Out:
# 891

# %%
cent_missing_values=round((train.isna().sum() / train.shape[0]) *100,2)
cent_missing_values
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
joined=pd.concat([missing_values, cent_missing_values], axis=1, keys=["missing_values", "cent_missing_values"])
joined
joined=joined[joined["missing_values"]>0]
joined
# Out:
#           missing_values  cent_missing_values
# Age                  177                19.87
# Cabin                687                77.10
# Embarked               2                 0.22

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Data Cleaning

# %%
# filling missing values in age column with mean
mean_age=round(   train["Age"].mean())



mean_age

train["Age"].fillna(mean_age, inplace=True)

# %%
# convert the datatype of age column to int

train["Age"] = train["Age"].astype(int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 80.2+ KB

# %%
# To convert a series to sting
#extracting the first letter of the cabins

train["Cabin"]
train["Cabin"].str[0]
train["Cabin"]=train["Cabin"].str[0]

# %%
# Fill missing value in cabin colum with mode

mode_cabin = train["Cabin"].mode()[0]
train["Cabin"].fillna(mode_cabin, inplace=True)

# %%
train["Cabin"]
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 886    C
# 887    B
# 888    C
# 889    C
# 890    C
# Name: Cabin, Length: 891, dtype: object

# %%
# Fill missing value in cabin colum with mode

mode_embarked = train["Embarked"].mode()[0]
train["Embarked"].fillna(mode_embarked, inplace=True)

# %%
train["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# # Data Exploration
#
# This is the process of analysing the data to bring out hidden pattern in the datasets
# - Uni-variate Analysis: analysing one colums at a time
# - Bi-variate Analysis: analysin two columns at a time
# - Multi-variate Analysis: analysing more than two columns at a time

# %%
# Uni-variate Analysis

# %%
survived=train["Survived"].value_counts()
survived.index=["dead","survived"]
survived
# Out:
# dead        549
# survived    342
# Name: Survived, dtype: int64

# %%
# Pandas plot

survived.plot(kind="bar", color= ["orange", "green"])
plt.title("Count of Survival", color="blue")
plt.xticks(rotation=50, color="black")
plt.yticks(rotation=50, color="black")
plt.show()

# %%
sex=train["Sex"].value_counts()
sex
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sex.plot(kind="bar", color= ["orange", "green"])
plt.title("Count of Gender", color="purple")
plt.xticks(rotation=50, color="black")
plt.yticks(rotation=50, color="black")
plt.show()

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# to check unique value
train["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
# to check number of uniqu data in a colum
train["SibSp"].nunique()
# Out:
# 7

# %%
count_of_sibling=train["SibSp"].value_counts()
count_of_sibling
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
# Mat Plot

plt.bar(x=count_of_sibling.index, height=count_of_sibling.values)
plt.title("count of sibling", color="purple")
plt.xticks(rotation=50, color="black")
plt.yticks(rotation=50, color="black")
plt.show()

# %%
count_of_Embarked=train["Embarked"].value_counts()
count_of_Embarked
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sns.barplot(x=count_of_Embarked.index, y=count_of_Embarked.values)
plt.title("count of Embarked", color="purple")
plt.xticks(rotation=50, color="black")
plt.yticks(rotation=50, color="black")
plt.show()

# %%
train["Age"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
count_of_Pclass=train["Pclass"].value_counts()
count_of_Pclass
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
count_of_Pclass.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bi-Variance Analysis

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# query the dataframe when survived column is 0
train.query("Survived==0")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# query the dataframe when survived columnn is 0 and return sex column
train.query("Survived==0")["Sex"]
# Out:
# 0        male
# 4        male
# 5        male
# 6        male
# 7        male
#         ...
# 884      male
# 885    female
# 886      male
# 888    female
# 890      male
# Name: Sex, Length: 549, dtype: object

# %%
# query the dataframe when survived column is 0 and return only sex column then make the count of sex
train.query("Survived==0")["Sex"].value_counts()
# Out:
# male      468
# female     81
# Name: Sex, dtype: int64

# %%
dead=train.query("Survived==0")["Sex"].value_counts()
alive=train.query("Survived==1")["Sex"].value_counts()

# %%
gender_survived_rate=pd.concat([dead, alive], keys=["dead", "alive"], axis=1)

# %%
gender_survived_rate.plot(kind='bar')
plt.ylim(0, 500)
plt.title("Gender Survived Rate", color="purple")
plt.xticks(rotation=50, color="black")
plt.yticks(rotation=50, color="black")
plt.show()

# %%
def barplot(feature):
    dead=train.query("Survived==0")[feature].value_counts()
    alive=train.query("Survived==1")[feature].value_counts()
    gender_survived_rate=pd.concat([dead, alive], keys=["dead", "alive"], axis=1)
    gender_survived_rate.plot(kind='bar')
    plt.ylim(0, 500)
    plt.title("Gender Survived Rate Per {}".format(feature), color="purple")
    plt.xticks(rotation=50, color="black")
    plt.yticks(rotation=50, color="black")
    plt.show()

# %%
barplot("Sex")

# %%
barplot("Embarked")

# %%
barplot("Pclass")

# %%
barplot("Cabin")

# %%
barplot("SibSp")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# bi-variance for category and number
chart= sns.FacetGrid(train, hue="Survived", aspect=4)
chart.map(sns.kdeplot, "Age", shade=True)
chart.add_legend()
plt.title("Survived rate VS Age")
plt.show()

# %%
sns.scatterplot(x=train["Age"], y=train["Fare"])
chart.add_legend()
plt.title("Age VS Fare")
plt.show()
